# %%
import numpy as np
import pandas as pd
import timeit
import time
import matplotlib.pyplot as plt
import random
import scipy.io

# %%
import tensorflow.compat.v1 as tf
from tqdm import tqdm
import timeit 
tf.disable_v2_behavior()
# Out:
# 2023-08-03 21:33:31.609612: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-03 21:33:31.611266: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 21:33:31.641341: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-03 21:33:31.641895: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-03 21:33:32.404395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/eo3j/.conda/envs/tf-2.0/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
dat1 =pd.read_csv('data11.csv')
dat1.head()
# Out:
#      t        u1        u2
# 0  0.0  1.000000  0.000000
# 1  0.1  0.606531  0.372883
# 2  0.2  0.367879  0.563564
# 3  0.3  0.223130  0.647110
# 4  0.4  0.135335  0.668731

# %%
z1_new = np.array(dat1["u1"]).flatten()[:,None]
z2_new = np.array(dat1["u2"]).flatten()[:,None]
t_new = np.array(dat1["t"]).flatten()[:,None]

# %%
from scipy import interpolate

# Assuming that the 't_data' array is the independent variable and 'z1_data' and 'z2_data' are dependent variables
t_data = np.linspace(t_new.min(), t_new.max(), 100)[:, None]  # generating 500 points

# Interpolation for z1_data
f_z1 = interpolate.interp1d(t_new.flatten(), z1_new.flatten(), kind='cubic')  # 'cubic' for cubic spline interpolation
z1_data = f_z1(t_data)

# Interpolation for z2_data
f_z2 = interpolate.interp1d(t_new.flatten(), z2_new.flatten(), kind='cubic')  # 'cubic' for cubic spline interpolation
z2_data = f_z2(t_data)

# %%
plt.plot(t_data, z1_data,"-")
plt.plot(t_data, z2_data,"-")
plt.show()

# %%
class PINN:
    # Initialize the class
    def __init__(self, t, z1, z2, layers, layers1, layers2):
        
        self.lb = t.min(0)
        self.ub = t.max(0)
        
        self.t = t
        
        self.z1 = z1
        self.z2 = z2
        
        self.layers = layers
        self.layers1 = layers1
        self.layers2 = layers2
        
        self.weights, self.biases = self.initialize_NN(layers)
        self.weights1, self.biases1 = self.initialize_NN(layers1)
        self.weights2, self.biases2 = self.initialize_NN(layers2)
        
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        
        
        
        self.t_tf = tf.placeholder(tf.float32, shape=[None, self.t.shape[1]])
        self.z1_tf = tf.placeholder(tf.float32, shape=[None, self.z1.shape[1]])
        self.z2_tf = tf.placeholder(tf.float32, shape=[None, self.z2.shape[1]])               
        
        
        self.z1_pred, self.z2_pred = self.net_ASIR(self.t_tf)
        self.aa_pred = self.aa_net(self.t_tf)
        self.bb_pred = self.bb_net(self.t_tf)
        
        self.l1, self.l2 = self.net_l(self.t_tf)
        
        
        self.loss = tf.reduce_sum(tf.square(self.z1_tf - self.z1_pred)) + \
                    tf.reduce_sum(tf.square(self.z2_tf - self.z2_pred)) + \
                    tf.reduce_sum(tf.square(self.l1)) + \
                    tf.reduce_sum(tf.square(self.l2))
        
        
        self.train_op = tf.train.AdamOptimizer().minimize(self.loss)
        self.loss_log = []
        init = tf.global_variables_initializer()
        self.sess.run(init)
        

    def initialize_NN(self, layers):        
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0,num_layers-1):
            W = self.xavier_init(size=[layers[l], layers[l+1]])
            b = tf.Variable(tf.zeros([1,layers[l+1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)        
        return weights, biases
        
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2/(in_dim + out_dim))
        return tf.Variable(tf.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def neural_net(self, t, layers, weights, biases):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights[l]
            b = biases[l]
            H = tf.sigmoid(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
        
    def neural_net1(self, t, layers1, weights1, biases1):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights1[l]
            b = biases1[l]
            H = tf.sigmoid(tf.add(tf.matmul(H, W), b))
        W = weights1[-1]
        b = biases1[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    def neural_net2(self, t, layers2, weights2, biases2):
        num_layers = len(layers1)
        
        H = 2.0*(t - self.lb)/(self.ub - self.lb) - 1.0
        for l in range(0,num_layers-2):
            W = weights2[l]
            b = biases2[l]
            H = tf.sigmoid(tf.add(tf.matmul(H, W), b))
        W = weights2[-1]
        b = biases2[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y
    
    
    def net_ASIR(self, t):
        ASIR = self.neural_net(t, self.layers, self.weights, self.biases)
        z1 = ASIR[:,0:1]
        z2 = ASIR[:,1:2]
        
        return z1, z2
    
    def aa_net(self,t):
        aa = self.neural_net1(t, self.layers1, self.weights1, self.biases1)
        alp = aa
        return alp
    
    def bb_net(self,t):
        bb = self.neural_net2(t, self.layers2, self.weights2, self.biases2)
        blp = bb
        return blp
    
    
    
    def net_l(self, t):
        z1, z2 = self.net_ASIR(t)
        aa = self.aa_net(t)
        bb = self.bb_net(t)
        
        z1_t = tf.gradients(z1, t)[0]
        z2_t = tf.gradients(z2, t)[0]
        
        l1 = z1_t + aa*z1
        l2 = z2_t - (aa*z1 - bb*z2)
        
        return l1, l2 
    
    
        
        
    def train(self, nIter):
        tf_dict = {self.t_tf: self.t, self.z1_tf: self.z1, self.z2_tf: self.z2}
        start_time = timeit.default_timer()

        for it in tqdm(range(nIter)):
            self.sess.run(self.train_op, tf_dict)
            if it % 100 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                self.loss_log.append(loss_value)
                start_time = timeit.default_timer()
                
    def predict(self, t_star):
        tf_dict = {self.t_tf: t_star}
        
        z1_star = self.sess.run(self.z1_pred, tf_dict)
        z2_star = self.sess.run(self.z2_pred, tf_dict)
        aa_star = self.sess.run(self.aa_pred, tf_dict)
        bb_star = self.sess.run(self.bb_pred, tf_dict)
        
        return z1_star, z2_star, aa_star, bb_star

# %%
niter = 90000  # number of Epochs
layers = [1, 40, 2]
layers1 = [1, 40, 1]
layers2 = [1, 40, 1]

model = PINN(t_data, z1_data, z2_data, layers, layers1, layers2)
model.train(niter)
# Out:
# Device mapping: no known devices.
# 2023-08-03 21:33:33.439087: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-08-03 21:33:33.834650: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 2023-08-03 21:33:33.837741: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837757: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837761: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837764: I tensorflow/core/common_runtime/placer.cc:114] Variable: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837768: I tensorflow/core/common_runtime/placer.cc:114] Variable/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837770: I tensorflow/core/common_runtime/placer.cc:114] Variable/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837773: I tensorflow/core/common_runtime/placer.cc:114] Variable_1: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837776: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837779: I tensorflow/core/common_runtime/placer.cc:114] Variable_1/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837782: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837785: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837788: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837791: I tensorflow/core/common_runtime/placer.cc:114] Variable_2: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837794: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837797: I tensorflow/core/common_runtime/placer.cc:114] Variable_2/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837800: I tensorflow/core/common_runtime/placer.cc:114] Variable_3: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837803: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837805: I tensorflow/core/common_runtime/placer.cc:114] Variable_3/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837808: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837811: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837814: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_2: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837820: I tensorflow/core/common_runtime/placer.cc:114] Variable_4: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837824: I tensorflow/core/common_runtime/placer.cc:114] Variable_4/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837826: I tensorflow/core/common_runtime/placer.cc:114] Variable_4/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837829: I tensorflow/core/common_runtime/placer.cc:114] Variable_5: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837832: I tensorflow/core/common_runtime/placer.cc:114] Variable_5/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837835: I tensorflow/core/common_runtime/placer.cc:114] Variable_5/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837839: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837842: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837845: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_3: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837849: I tensorflow/core/common_runtime/placer.cc:114] Variable_6: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837852: I tensorflow/core/common_runtime/placer.cc:114] Variable_6/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837854: I tensorflow/core/common_runtime/placer.cc:114] Variable_6/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837858: I tensorflow/core/common_runtime/placer.cc:114] Variable_7: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837861: I tensorflow/core/common_runtime/placer.cc:114] Variable_7/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837863: I tensorflow/core/common_runtime/placer.cc:114] Variable_7/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837866: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837870: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837873: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_4: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837877: I tensorflow/core/common_runtime/placer.cc:114] Variable_8: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837879: I tensorflow/core/common_runtime/placer.cc:114] Variable_8/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837882: I tensorflow/core/common_runtime/placer.cc:114] Variable_8/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837885: I tensorflow/core/common_runtime/placer.cc:114] Variable_9: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837889: I tensorflow/core/common_runtime/placer.cc:114] Variable_9/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837892: I tensorflow/core/common_runtime/placer.cc:114] Variable_9/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837895: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5/TruncatedNormal: (TruncatedNormal): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837898: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5/mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837901: I tensorflow/core/common_runtime/placer.cc:114] truncated_normal_5: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837904: I tensorflow/core/common_runtime/placer.cc:114] Variable_10: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837908: I tensorflow/core/common_runtime/placer.cc:114] Variable_10/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837911: I tensorflow/core/common_runtime/placer.cc:114] Variable_10/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837914: I tensorflow/core/common_runtime/placer.cc:114] Variable_11: (VariableV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837917: I tensorflow/core/common_runtime/placer.cc:114] Variable_11/Assign: (Assign): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837923: I tensorflow/core/common_runtime/placer.cc:114] Variable_11/read: (Identity): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837927: I tensorflow/core/common_runtime/placer.cc:114] sub: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837930: I tensorflow/core/common_runtime/placer.cc:114] mul: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837934: I tensorflow/core/common_runtime/placer.cc:114] truediv: (RealDiv): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837937: I tensorflow/core/common_runtime/placer.cc:114] sub_1: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837941: I tensorflow/core/common_runtime/placer.cc:114] MatMul: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837960: I tensorflow/core/common_runtime/placer.cc:114] Add: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837964: I tensorflow/core/common_runtime/placer.cc:114] Sigmoid: (Sigmoid): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837967: I tensorflow/core/common_runtime/placer.cc:114] MatMul_1: (MatMul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837971: I tensorflow/core/common_runtime/placer.cc:114] Add_1: (AddV2): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837974: I tensorflow/core/common_runtime/placer.cc:114] strided_slice: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837977: I tensorflow/core/common_runtime/placer.cc:114] strided_slice_1: (StridedSlice): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837981: I tensorflow/core/common_runtime/placer.cc:114] sub_2: (Sub): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.837984: I tensorflow/core/common_runtime/placer.cc:114] mul_1: (Mul): /job:localhost/replica:0/task:0/device:CPU:0
# 2023-08-03 21:33:33.
grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/mul_3_grad/Sum_1_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/mul_3_grad/Sum_1_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/truediv_3_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/truediv_3_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/truediv_3_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/truediv_3_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/truediv_3_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/truediv_3_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/truediv_3_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/truediv_3_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/truediv_3_grad/RealDiv_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/truediv_3_grad/RealDiv_grad/Shape_1: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/sub_7_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/sub_7_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/sub_7_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/sub_7_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/sub_7_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/sub_7_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/sub_7_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/sub_7_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Add_6_grad/Sum_grad/Size: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Add_6_grad/Sum_grad/range/start: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Add_6_grad/Sum_grad/range/delta: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients_1/Add_6_grad/Sum_grad/ones/Const: (Const): /job:localhost/replica:0/task:0/device:CPU:0
# gradients_2/gradients/Add_6_grad/Sum_grad/Size
# 100%|██████████| 90000/90000 [00:41<00:00, 2187.76it/s]

# %%
# prediction
z1_pred, z2_pred, aa_pred, bb_pred = model.predict(t_data)

# %%
dat11 =pd.read_csv('data11.csv')
dat11.head()
# Out:
#      t        u1        u2
# 0  0.0  1.000000  0.000000
# 1  0.1  0.606531  0.372883
# 2  0.2  0.367879  0.563564
# 3  0.3  0.223130  0.647110
# 4  0.4  0.135335  0.668731

# %%
z11_data = np.array(dat11["u1"]).flatten()[:,None]
z21_data = np.array(dat11["u2"]).flatten()[:,None]
t1_data = np.array(dat11["t"]).flatten()[:,None]

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(t_data,z1_data,'r')
plt.plot(t1_data,z11_data,'ko')
plt.plot(t_data,z1_pred,'g--')

plt.plot(t_data,z2_data,'b')
plt.plot(t1_data,z21_data,'o')
plt.plot(t_data,z2_pred,'m--')

plt.xlabel('t_data')
plt.ylabel("Species z1 and z2")
plt.grid(True)
plt.legend(["t_data vs Species z1", "z1 data", "t_data vs Predicted Species z1", "t_data vs Species z2", "z2 data", "t_data vs Predicted Species z2"])
plt.title("Irreversible Chemical Reactions")
  
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10,8]
plt.plot(z1_data,z2_data,'b')
plt.plot(z1_pred,z2_pred,'r--')
plt.legend(["Actual-Output", "Predicted-Output"])
plt.xlabel('Species z1')
plt.ylabel("Species z2")
plt.title("Phase Space plot")
plt.show()

# %%
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(t_data,aa_pred,'k--')
plt.plot(t_data,bb_pred,'r--')

plt.xlabel('t_data')
plt.ylabel("k1 and k2 Parameter")
plt.legend(["k1 Parameter", "k2 Parameter"])
plt.grid(True)
plt.title("Irreversible Chemical Reactions Parameters")
  
plt.show()

# %%
import numpy as np

aa = 5  # initial parameter

# Using list comprehension and abs() function to calculate absolute differences
diffs = [abs(aa - i) for i in aa_pred]

# Using np.argmin() to find the index of smallest difference
index_min_diff = np.argmin(diffs)

# Getting the best predicted value
best_preda = aa_pred[index_min_diff]

# Getting the time of the best prediction
best_pred_time = t_data[index_min_diff]


# Print the best predicted value, its time step, and the actual time
print(f"The best predicted value is {best_preda} at time step {index_min_diff}, which occurred at {best_pred_time}.")
# Out:
# The best predicted value is [5.0005193] at time step 22, which occurred at [0.22222222].

# %%
import numpy as np

bb = 1  # initial parameter

# Using list comprehension and abs() function to calculate absolute differences
diffs = [abs(bb - i) for i in bb_pred]

# Using np.argmin() to find the index of smallest difference
index_min_diff = np.argmin(diffs)

# Getting the best predicted value
best_predb = bb_pred[index_min_diff]

# Getting the time of the best prediction
best_pred_time = t_data[index_min_diff]


# Print the best predicted value, its time step, and the actual time
print(f"The best predicted value is {best_predb} at time step {index_min_diff}, which occurred at {best_pred_time}.")
# Out:
# The best predicted value is [1.0001917] at time step 27, which occurred at [0.27272727].

# %%
from scipy.integrate import odeint

def system(u, t, k1, k2):
    du1_dt = -k1 * u[0]
    du2_dt = k1 * u[0] - k2 * u[1]
    return [du1_dt, du2_dt]

# Values for k1 and k2 (you need to provide the appropriate values)
k1 = best_preda[0]# If best_preda is a one-dimensional array
k2 = best_predb[0]  # If best_predb is a one-dimensional array

# Generate more points for a smoother plot
t_fine = np.linspace(t_data.min(), t_data.max(), 100)

initial_conditions = [1.0, 0.0]
u_fine = odeint(system, initial_conditions, t_fine, args=(k1, k2))


# Generate points for original t values (make sure t_new is defined properly)
t_new = np.array(dat1["t"]).flatten()
u_pred = odeint(system, initial_conditions, t_new, args=((k1, k2)))

u1_u2 = np.hstack((z1_new, z2_new))


# # plot the absolute errors between the target and the predictions (make sure u1_u2 and t are defined properly)
plt.rcParams['figure.figsize'] = [10, 8]
plt.plot(t_new, np.abs(u1_u2[:, 0] - u_pred[:, 0]), 'r')
plt.plot(t_new, np.abs(u1_u2[:, 1] - u_pred[:, 1]), 'g')
plt.xlabel('t_data')
plt.ylabel("Absolute Errors")
plt.legend(["t_data vs Absolute Errors for z1", "t_data vs Absolute Errors for z2"])
plt.grid(True)
plt.title("Absolute Errors vs t_data")
plt.show()

# %%
# calculate the loss
loss = model.sess.run(model.loss, {model.t_tf: t_data, model.z1_tf: z1_data, model.z2_tf: z2_data})
print("Loss:", loss)

# plot the loss
plt.rcParams['figure.figsize'] = [10, 10]
plt.plot(model.loss_log)
plt.xlabel('Epochs')
plt.ylabel("Loss")
plt.title("Loss vs Epochs")
plt.show()

# calculate the R-squared
from sklearn.metrics import r2_score
r2_u1 = r2_score(u1_u2[:, 0], u_pred[:, 0])
r2_u2 = r2_score(u1_u2[:, 1], u_pred[:, 1])
print(f"R-squared for u1: {r2_u1}")
print(f"R-squared for u2: {r2_u2}")

# calculate the mean absolute error
from sklearn.metrics import mean_absolute_error
mae_u1 = mean_absolute_error(u1_u2[:, 0], u_pred[:, 0])
mae_u2 = mean_absolute_error(u1_u2[:, 1], u_pred[:, 1])
print(f"Mean absolute error for u1: {mae_u1}")
print(f"Mean absolute error for u2: {mae_u2}")

# calculate the mean squared error
from sklearn.metrics import mean_squared_error
mse_u1 = mean_squared_error(u1_u2[:, 0], u_pred[:, 0])
mse_u2 = mean_squared_error(u1_u2[:, 1], u_pred[:, 1])
print(f"Mean squared error for u1: {mse_u1}")
print(f"Mean squared error for u2: {mse_u2}")

# calculate the root mean squared error
from sklearn.metrics import mean_squared_error
rmse_u1 = mean_squared_error(u1_u2[:, 0], u_pred[:, 0], squared=False)
rmse_u2 = mean_squared_error(u1_u2[:, 1], u_pred[:, 1], squared=False)
print(f"Root mean squared error for u1: {rmse_u1}")
print(f"Root mean squared error for u2: {rmse_u2}")

# calculate the Explained variance score
from sklearn.metrics import explained_variance_score
evs_u1 = explained_variance_score(u1_u2[:, 0], u_pred[:, 0])
evs_u2 = explained_variance_score(u1_u2[:, 1], u_pred[:, 1])
print(f"Explained variance score for u1: {evs_u1}")
print(f"Explained variance score for u2: {evs_u2}")
# Out:
# Loss: 0.00087031734
# R-squared for u1: 0.999999994678141
# R-squared for u2: 0.9999999394013943
# Mean absolute error for u1: 1.7826949633502895e-05
# Mean absolute error for u2: 3.731017353407852e-05
# Mean squared error for u1: 4.835832364681245e-10
# Mean squared error for u2: 2.0367626246530452e-09
# Root mean squared error for u1: 2.199052606165038e-05
# Root mean squared error for u2: 4.5130506585380195e-05
# Explained variance score for u1: 0.9999999981755482
# Explained variance score for u2: 0.9999999625396087
